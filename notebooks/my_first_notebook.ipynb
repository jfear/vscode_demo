# %% [markdown]
# # My First Notebook

# %%
print("Hello Word!")
# Out:
# Hello Word!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.hist(np.random.normal(size=1000))
# Out:
# (array([  6.,  27.,  76., 189., 264., 244., 133.,  47.,  12.,   2.]),
#  array([-3.25936815, -2.57847377, -1.89757939, -1.21668501, -0.53579063,
#          0.14510376,  0.82599814,  1.50689252,  2.1877869 ,  2.86868128,
#          3.54957566]),
#  <BarContainer object of 10 artists>)
